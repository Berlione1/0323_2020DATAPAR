# %%
headers='https://www.zalando.fr/api/catalog/articles?campaigns=mu_sneaker_releases&categories=homme&limit=84&offset=84'

# %%
import pandas as pd
import requests as r
import time
import json

# %%
df_final=pd.DataFrame()
for i in range(100):
    url=f'https://www.zalando.fr/api/catalog/articles?campaigns=mu_sneaker_releases&categories=homme&limit=84&offset={84*i}'
    headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: fvgs_ml=mosaic; Zalando-Client-Id=43b67b97-fed2-4a79-b7dd-9ba0cc474b7e; _ga=GA1.2.1781348139.1586261574; _gid=GA1.2.952937853.1586261578; _gcl_au=1.1.337073708.1586261578; frsx=AAAAAO7DoCm2LcmNIG8hcgXncNnB0EHV9W5gKz3eiTo4jFTXOfa9KbAF9yWVbc8YkI8QayJHYwgTJlh4vWx_Sr0gJFjE0HdZ0E-RC2Xh4QPsOx6pQeCRdllKdRk8AtwC43QvOwtT4OdqjVhILWutrQc=; bm_sz=5447FBCFB88A351D0634B42F03225888~YAAQFex7XHwU8FhxAQAAJUz9WAcpE4G6Zt61Ss1amp1TC9xP1mQeKQ+5X3DifF+8b6HOZW693JBvlNfJz6UEsVqnhgBwqWj+BmiQ2cFRkYrlfUFB/PdFNcPfu6XNTXRSNW/p8KGS1HZXBs7oNnfWds+MNykFfPH0NO6iI9vZlM8kQUk5GyEq8aRDSUAlUs9t; ak_bmsc=B0011D8E60170666147AA0253B0CA10B5C7BEC151E700000B7908D5E82AD6670~; _gac_UA-19190613-1=1.1586335940.Cj0KCQjwybD0BRDyARIsACyS8mvTuRIW0oXQ6RYPuTqP7UJ_nDyhygapVWsiChJq1BfCGxtpyccXWqUaAsAZEALw_wcB; _gcl_aw=GCL.1586335940.Cj0KCQjwybD0BRDyARIsACyS8mvTuRIW0oXQ6RYPuTqP7UJ_nDyhygapVWsiChJq1BfCGxtpyccXWqUaAsAZEALw_wcB; _gcl_dc=GCL.1586335940.Cj0KCQjwybD0BRDyARIsACyS8mvTuRIW0oXQ6RYPuTqP7UJ_nDyhygapVWsiChJq1BfCGxtpyccXWqUaAsAZEALw_wcB; ncx=m; _gat_zalga=1; _abck=0C1158F0863CDB5387D391E1B02474F4~-1~~-1~-1~-1
pragma: no-cache
referer: https://www.zalando.fr/homme/?camp=mu_sneaker_releases
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36
x-xsrf-token: AAAAAO7DoCm2LcmNIG8hcgXncNnB0EHV9W5gKz3eiTo4jFTXOfa9KbAF9yWVbc8YkI8QayJHYwgTJlh4vWx_Sr0gJFjE0HdZ0E-RC2Xh4QPsOx6pQeCRdllKdRk8AtwC43QvOwtT4OdqjVhILWutrQc=
x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22homme%22%5D%2C%22previous_selected_filters%22%3A%5B%7B%22key%22%3A%22campaigns%22%2C%22values%22%3A%5B%22mu_sneaker_releases%22%5D%2C%22kind%22%3A%22values%22%7D%5D%2C%22preselected_filters%22%3A%5B%7B%22key%22%3A%22campaigns%22%2C%22values%22%3A%5B%22mu_sneaker_releases%22%5D%2C%22kind%22%3A%22values%22%7D%5D%7D
x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22eager-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-43b67b97-fed2-4a79-b7dd-9ba0cc474b7e%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""
    headers=dict([i.strip().split(': ') for i in headers.split('\n')])
    results=r.get(url,headers=headers).json()
    df=pd.json_normalize(results['articles'])
    df_final=df_final.append(df)
    time.sleep(2)

# %%
df_final
# Out:
#               sku                                               name  \
# 0   NI112O0CD-A11  AIR MAX 2090 - Baskets basses - white/black/pu...
# 1   NI112O0CD-K11  AIR MAX 2090 - Baskets basses - ice blue/black...
# 2   CO415N08I-A11  CHUCK TAYLOR ALL STAR 70  - Baskets montantes ...
# 3   NI112O0DS-A11  AIR FORCE 1 '07 LV8 - Baskets basses - white/b...
# 4   NI112O0BW-A12  REACT 55 - Baskets basses - white/laser crimso...
# ..            ...                                                ...
# 6   AD115O0GF-A12  RIVALRY BASKETBALL-STYLE SHOES - Baskets basse...
# 7   VA215N014-M11  SK8 REISSUE - Baskets montantes - black/sharp ...
# 8   S2315O00A-M11              AZURA - Baskets basses - green/yellow
# 9   VA215O02I-K11  PARADOXXX - Baskets basses - smoke blue/marshm...
# 10  VA215O040-A11  CLASSIC SLIP-ON - Baskets basses - black/true ...
#
#                                                 sizes  \
# 0   [37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...
# ...

# %%
df_final.sku.duplicated().sum()
# Out:
# 0
