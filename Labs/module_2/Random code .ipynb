# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\galic156685\Downloads\housing_prices.csv')

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df=df.convert_dtypes()

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.Id.nunique()==df.shape[0]
# Out:
# True

# %%
df.drop('Id',axis=1,inplace=True)

# %%
missing=df.isna().sum()
missing[missing>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df.MiscFeature.unique()
# Out:
# <StringArray>
# [<NA>, 'Shed', 'Gar2', 'Othr', 'TenC']
# Length: 5, dtype: string

# %%
df.MiscFeature.value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: Int64

# %%
dummies_list_NA=['MiscFeature']

# %%
df.Fence.unique()
# Out:
# <StringArray>
# [<NA>, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw']
# Length: 5, dtype: string

# %%
df.Fence.value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: Int64

# %%
df[['Fence','SalePrice']].groupby('Fence').agg('mean')
# Out:
#            SalePrice
# Fence
# GdPrv  178927.457627
# GdWo   140379.314815
# MnPrv  148751.089172
# MnWw   134286.363636

# %%
df.PoolQC.unique()
# Out:
# <StringArray>
# [<NA>, 'Ex', 'Fa', 'Gd']
# Length: 4, dtype: string

# %%
dct={'Ex':5,'Fa':2,'Gd':4}
df.PoolQC=df.PoolQC.map(dct)
df.PoolQC.fillna(0,inplace=True)

# %%
df.PoolQC.value_counts()
# Out:
# 0.0    1457
# 2.0       2
# 3.0       1
# Name: PoolQC, dtype: int64

# %%
dct={'Ex':5,'Fa':2,'Gd':4,'TA':3,'Po':1}
df.GarageQual=df.GarageQual.map(dct)
df.GarageQual.fillna(0,inplace=True)

# %%
dct={'Ex':5,'Fa':2,'Gd':4,'TA':3,'Po':1}
df.GarageCond=df.GarageCond.map(dct)
df.GarageCond.fillna(0,inplace=True)

# %%
dct={'Rfn':2,'Fin':3,'Unf':1}
df.GarageFinish=df.GarageFinish.map(dct)
df.GarageFinish.fillna(0,inplace=True)

# %%
df.drop('GarageYrBlt',axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL           65     8450   Pave  <NA>      Reg
# 1             20       RL           80     9600   Pave  <NA>      Reg
# 2             60       RL           68    11250   Pave  <NA>      IR1
# 3             70       RL           60     9550   Pave  <NA>      IR1
# 4             60       RL           84    14260   Pave  <NA>      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL           62     7917   Pave  <NA>      Reg
# 1456          20       RL           85    13175   Pave  <NA>      Reg
# 1457          70       RL           66     9042   Pave  <NA>      Reg
# 1458          20       RL           68     9717   Pave  <NA>      Reg
# 1459          20       RL           75     9937   Pave  <NA>      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df.GarageType.value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: Int64

# %%
dummies_list_NA.append('GarageType')

# %%
df.FireplaceQu.value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: Int64

# %%
dct={'Ex':5,'Fa':2,'Gd':4,'TA':3,'Po':1}
df.FireplaceQu=df.FireplaceQu.map(dct)
df.FireplaceQu.fillna(0,inplace=True)

# %%
df.Electrical.value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: Int64

# %%
df[df. Electrical.isna()].YearBuilt
# Out:
# 1379    2006
# Name: YearBuilt, dtype: Int64

# %%
df.query('2004<YearBuilt<2018').Electrical
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f393fe0221f8> in <module>
# ----> 1 df.query('2004<YearBuilt<2018').Electrical
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ...

# %%
df.loc[df.Electrical.isna]

# %%
dummises_list=['Electrical']

# %%
pd.concat([df,df[['BsmtFinType1','BsmtFinType2']].stack().str.get_dummies().sum(level=0)],axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL           65     8450   Pave  <NA>      Reg
# 1             20       RL           80     9600   Pave  <NA>      Reg
# 2             60       RL           68    11250   Pave  <NA>      IR1
# 3             70       RL           60     9550   Pave  <NA>      IR1
# 4             60       RL           84    14260   Pave  <NA>      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL           62     7917   Pave  <NA>      Reg
# 1456          20       RL           85    13175   Pave  <NA>      Reg
# 1457          70       RL           66     9042   Pave  <NA>      Reg
# 1458          20       RL           68     9717   Pave  <NA>      Reg
# 1459          20       RL           75     9937   Pave  <NA>      Reg
#
#      LandContour Utilities LotConfig  ... YrSold SaleType SaleCondition  \
# ...
