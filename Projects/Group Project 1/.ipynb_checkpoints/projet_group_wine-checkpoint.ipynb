# %% [markdown]
# # Group Project : Wine vs weather Analysis

# %% [markdown]
# ## Import of libraries

# %%
import pandas as pd
import requests as r
import json
import time
import matplotlib.pyplot as plt
import re
import numpy as np

# %% [markdown]
# ## Import of files

# %%
path_data = r"C:\Users\galic156685\0323_2020DATAPAR\Projects"

data_w = pd.read_csv("2124520.csv",",")
data_v = pd.read_csv("vivino.csv")

# %% [markdown]
# ## Merging of the wine data and the weather data

# %% [markdown]
# ### Definition of the dictionnary

# %%
dct_stations = {'bordeaux': 'BORDEAUX MERIGNAC, FR',
       'languedoc-roussillon':  'MONTPELLIER AEROPORT, FR',
       'cote-de-beaune': 'DIJON LONGVIC, FR',
       'cote-de-nuits': 'DIJON LONGVIC, FR' ,
       'rhone': 'LYON ST EXUPERY, FR',
       'loire-valley': 'NANTES BOUGUENAIS, FR',
       'bourgogne': 'DIJON LONGVIC, FR',
       'champagne': 'REIMS PRUNAY, FR',
       'alsace': 'STRASBOURG ENTZHEIM, FR',
       'chateauneuf-du-pape': 'MONTELIMAR, FR'}

### READ DF VIVINO

data_v['station']=data_v["vintage.wine.style.region.seo_name"].map(dct_stations)

#print(data_v.head())

#print(data_v.groupby('station').count())

data_w
# Out:
#          STATION                     NAME  DATE  DX32   DX70  DX90  FZF2  \
# 0    FR000007510    BORDEAUX MERIGNAC, FR  1980   0.0   98.0   2.0  21.0
# 1    FR000007510    BORDEAUX MERIGNAC, FR  1981   0.0  123.0   6.0   NaN
# 2    FR000007510    BORDEAUX MERIGNAC, FR  1982   0.0  127.0   3.0   NaN
# 3    FR000007510    BORDEAUX MERIGNAC, FR  1983   0.0  134.0   8.0  23.0
# 4    FR000007510    BORDEAUX MERIGNAC, FR  1984   0.0  114.0   6.0   NaN
# ..           ...                      ...   ...   ...    ...   ...   ...
# 275  FR000007190  STRASBOURG ENTZHEIM, FR  2014   3.0  139.0   6.0  17.0
# 276  FR000007190  STRASBOURG ENTZHEIM, FR  2015   0.0  122.0  22.0   NaN
# 277  FR000007190  STRASBOURG ENTZHEIM, FR  2016  10.0  122.0  10.0  20.0
# 278  FR000007190  STRASBOURG ENTZHEIM, FR  2017  11.0  139.0  14.0   NaN
# 279  FR000007190  STRASBOURG ENTZHEIM, FR  2019   NaN    NaN   NaN   NaN
#
#       PRCP  TAVG  TMAX  TMIN
# 0    36.06  54.0  62.2  45.8
# 1    38.97  55.8  64.2  47.4
# 2    45.89  56.4  64.8  48.1
# 3    34.12  56.1  64.6  47.6
# 4    46.99  54.7  63.2  46.3
# ..     ...   ...   ...   ...
# 275  26.52  54.7  63.3  46.1
# 276  18.69  54.1  63.1  45.1
# 277  28.75  52.9  61.2  44.7
# 278  23.79  53.5  62.4  44.6
# 279  22.91   NaN   NaN   NaN
#
# [280 rows x 11 columns]

# %% [markdown]
# ### Merge of the two Dataframes

# %%
#Creation of the merge columns

data_v['join']=data_v.apply(lambda row:(row['station']) +((row['vintage.year'])),axis=1)
data_w['join']=data_w.apply(lambda row:(row['NAME'])+(row['DATE']),axis=1)

####### Merge of the 2 DateFrame

data=data_v.merge(data_w,on='join')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-cac7434d3d27> in <module>
#       1 #Creation of the merge columns
#       2
# ----> 3 data_v['join']=data_v.apply(lambda row:(row['station']) +((row['vintage.year'])),axis=1)
#       4 data_w['join']=data_w.apply(lambda row:(row['NAME'])+(row['DATE']),axis=1)
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-34-cac7434d3d27> in <lambda>(row)
#       1 #Creation of the merge columns
#       2
# ----> 3 data_v['join']=data_v.apply(lambda row:(row['station']) +((row['vintage.year'])),axis=1)
#       4 data_w['join']=data_w.apply(lambda row:(row['NAME'])+(row['DATE']),axis=1)
#       5
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
data_v.isna().sum()
data_w.isna().sum()

# %%
data_v["vintage.year"]=data_v["vintage.year"].replace("N.V.",0)

# %% [markdown]
# ## Data Cleaning of the new database

# %%
data.shape
# Out:
# (95745, 21)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'vintage.wine.winery.seo_name',
#        'vintage.wine.winery.name', 'vintage.wine.name', 'vintage.year',
#        'vintage.statistics.ratings_average', 'vintage.wine.region.name',
#        'vintage.wine.region.seo_name', 'vintage.wine.style.region.seo_name',
#        'station', 'Year', 'join', 'STATION', 'NAME', 'DATE', 'CLDD', 'HTDD',
#        'PRCP', 'TAVG', 'TMAX', 'TMIN'],
#       dtype='object')

# %%
#Cleaning column
data = data[['vintage.wine.winery.name', 'vintage.wine.region.name', 'vintage.year',
       'vintage.statistics.ratings_average', 'vintage.wine.style.region.seo_name',
           'Year','NAME','DATE', 'CLDD', 'HTDD','PRCP', 'TAVG', 'TMAX','TMIN']]
data.DATE=data.Year.apply(lambda x:x[-2:])
data=data.rename(columns={'DATE':'month','vintage.wine.winery.name':'domaine','vintage.wine.region.name':'appelation','vintage.year':'year','vintage.statistics.ratings_average':'rate'})
i=data[data.year==1998].index
data.drop(i)
data
# Out:
#                       domaine           appelation  year  rate  \
# 0           Château Batailley             Pauillac  2013   4.1
# 1              Château Rouget              Pomerol  2013   3.9
# 2              Château Latour             Pauillac  2013   4.2
# 3              Château Meyney        Saint-Estèphe  2013   3.8
# 4             Château Olivier       Pessac-Léognan  2013   3.9
# ...                       ...                  ...   ...   ...
# 95740  Domaine de la Mordoree  Châteauneuf-du-Pape  1998   4.3
# 95741  Domaine de la Mordoree  Châteauneuf-du-Pape  1998   4.3
# 95742  Domaine de la Mordoree  Châteauneuf-du-Pape  1998   4.3
# 95743  Domaine de la Mordoree  Châteauneuf-du-Pape  1998   4.3
# 95744  Domaine de la Mordoree  Châteauneuf-du-Pape  1998   4.3
#
#       vintage.wine.style.region.seo_name     Year                   NAME  \
# 0                               bordeaux  2013-01  BORDEAUX MERIGNAC, FR
# 1                               bordeaux  2013-01  BORDEAUX MERIGNAC, FR
# 2                               bordeaux  2013-01  BORDEAUX MERIGNAC, FR
# 3                               bordeaux  2013-01  BORDEAUX MERIGNAC, FR
# 4                               bordeaux  2013-01  BORDEAUX MERIGNAC, FR
# ...                                  ...      ...                    ...
# 95740                chateauneuf-du-pape  1998-12         MONTELIMAR, FR
# 95741                chateauneuf-du-pape  1998-12         MONTELIMAR, FR
# 95742                chateauneuf-du-pape  1998-12         MONTELIMAR, FR
# 95743                chateauneuf-du-pape  1998-12         MONTELIMAR, FR
# 95744                chateauneuf-du-pape  1998-12         MONTELIMAR, FR
#
#       month  CLDD   HTDD   PRCP  TAVG  TMAX  TMIN
# 0        01   0.0  339.1  138.0   6.7   9.6   3.8
# 1        01   0.0  339.1  138.0   6.7   9.6   3.8
# 2        01   0.0  339.1  138.0   6.7   9.6   3.8
# 3        01   0.0  339.1  138.0   6.7   9.6   3.8
# 4        01   0.0  339.1  138.0   6.7   9.6   3.8
# ...     ...   ...    ...    ...   ...   ...   ...
# 95740    12   0.0  397.2   36.4   5.5   8.8   2.2
# 95741    12   0.0  397.2   36.4   5.5   8.8   2.2
# 95742    12   0.0  397.2   36.4   5.5   8.8   2.2
# 95743    12   0.0  397.2   36.4   5.5   8.8   2.2
# 95744    12   0.0  397.2   36.4   5.5   8.8   2.2
#
# [95745 rows x 14 columns]

# %% [markdown]
# ## Analyis of the data

# %%
bdx=data[data.NAME=='BORDEAUX MERIGNAC, FR']
cdn=data[(data.NAME=='DIJON LONGVIC, FR') & (data['vintage.wine.style.region.seo_name']=='cote-de-beaune')]
cdb=data[(data.NAME=='DIJON LONGVIC, FR') & (data['vintage.wine.style.region.seo_name']=='cote-de-nuit')]
lr=data[data.NAME=='MONTPELLIER AEROPORT, FR']
rh=data[data.NAME=='LYON ST EXUPERY, FR']
lv=data[data.NAME=='NANTES BOUGUENAIS, FR']
chmp=data[data.NAME=='REIMS PRUNAY, FR']
als=data[data.NAME=='STRASBOURG ENTZHEIM, FR']
cdp=data[data.NAME=='MONTELIMAR, FR']
brg=data[(data.NAME=='DIJON LONGVIC, FR') & (data['vintage.wine.style.region.seo_name']=='bourgogne')]

# %%
bdx[['year','domaine','rate']].groupby(['domaine',"year"]).agg('mean').nlargest(10,'rate')
# Out:
#                                 rate
# domaine                   year
# Château Ausone            2003   4.8
# Château Latour            2000   4.7
# Château d'Yquem           2004   4.7
# Château Mouton Rothschild 2000   4.7
# Château Cheval Blanc      2005   4.7
# Château Lafite Rothschild 2016   4.7
# Pétrus                    2008   4.7
# Château Pavie             2015   4.7
# Château Ausone            2007   4.7
#                           2006   4.7

# %%
bdx8=bdx[(bdx.month=='08')]

# %%
import seaborn as sns
sns.pairplot(bdx8, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
# Out:
# C:\Users\galic156685\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
a=chmp.groupby("year")["rate"].agg("mean").reset_index()
b=chmp.groupby("year")["TMAX"].agg("mean").reset_index()

# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize= (10,5))
# make a plot
ax.plot(a.year, a.rate, color="red", marker="o")
# set x-axis label
ax.set_xlabel("year",fontsize=14)
# set y-axis label
ax.set_ylabel("rate",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(b.year, b.TMAX,color="blue",marker="o")
ax2.set_ylabel("TMAX",color="blue",fontsize=14)
plt.show()
