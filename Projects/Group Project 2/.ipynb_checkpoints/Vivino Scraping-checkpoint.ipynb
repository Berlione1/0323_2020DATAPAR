# %%
import pandas as pd
import requests as r
import json
import time
import matplotlib.pyplot as plt
import re

# %%
df_final=pd.DataFrame()
for i in range(1):
    url=f'https://www.vivino.com/api/explore/explore?country_code=FR&country_codes[]=fr&currency_code=EUR&grape_filter=varietal&min_rating=1&order_by=ratings_count&order=desc&page={i+1}&price_range_max=500&price_range_min=0'
    headers="""accept: application/json
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
content-type: application/json
cookie: __auc=d250f01d171789f6bc01e099098; _ga=GA1.2.856886893.1586866646; _hjid=5928cd6c-01ab-408f-a7d0-4e498792d411; recently_viewed=--39e17ac97cea794bf53cb06b51c56bae6e20c4c4; client_cache_key=ZjVaMGFteVZQU0JqTmg0ZDRoYTMwRTd4b3ZyY3BnSVRxWVpsY0U2T3Vtdz0tLVVYTEwzeG1Pc3lJb1kzb2J2VldnNVE9PQ%3D%3D--904978d33f664888f1b960b8b4b5f9ce4bb77de6; _gid=GA1.2.1094377412.1588228071; _hp2_ses_props.3503103446=%7B%22r%22%3A%22https%3A%2F%2Fwww.google.com%2F%22%2C%22ts%22%3A1588228071374%2C%22d%22%3A%22www.vivino.com%22%2C%22h%22%3A%22%2F%22%7D; _hjIncludedInSample=1; _hp2_id.3503103446=%7B%22userId%22%3A%228842742331230353%22%2C%22pageviewId%22%3A%226147011832149692%22%2C%22sessionId%22%3A%227282908983421207%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; _ruby-web_session=...%3D%3D--1dce0a53e88e42d7e6c19aa4af71f1d7a5961e67
pragma: no-cache
referer: https://www.vivino.com/explore?e=eJzLLbI1VMvNzLM1UMtNrLA1NTBQS660dQtSS7Z1DQ1SKwDKpqfZliUWZaaWJOao5SfZFiWWZOalF8cn55fmlajl26akFicD9RRHx9qmFQEA9vAa3w==
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36
x-requested-with: XMLHttpRequest"""
    headers=dict([i.strip().split(': ') for i in headers.split('\n')])
    result=r.get(url, headers=headers).json()
    df=pd.json_normalize(result)
    df1=pd.json_normalize(df['explore_vintage.records'][0])
    df_final=df_final.append(df1)
    time.sleep(2)
    print(i)
# Out:
# 0

# %%
df_final.drop('vintage.wine.style.wine_type_id',axis=1,inplace=True)

# %%
df_final.head(1).T
# Out:
#                                                                                                     0
# vintage.statistics.ratings_count                                                                91657
# vintage.statistics.ratings_average                                                                4.6
# vintage.statistics.labels_count                                                                   311
# vintage.wine.id                                                                                 86684
# vintage.wine.type_id                                                                                3
# vintage.wine.is_natural                                                                         False
# vintage.wine.region.id                                                                            409
# vintage.wine.region.country.most_used_grapes        [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# ...

# %%
'3: Brut-champagne
# Out:
#   File "<ipython-input-112-6f9ece1e5650>", line 1
#     '3: Brut-champagne
#                       ^
# SyntaxError: EOL while scanning string literal
