# %%
import pandas as pd
import requests as r
import json
import time
import matplotlib.pyplot as plt
import re

# %%
url='https://www.nicolas.com/fr/Vins/c/01/results?q=:relevance&text=undefined&page=1'

# %%
r.get(url)
# Out:
# <Response [200]>

# %%
df_final=pd.DataFrame()
for i in range(5):
    url=f'https://www.nicolas.com/fr/Vins/c/01/results?q=:relevance&text=undefined&page={i}'
    headers="""Accept: application/json, text/javascript, */*; q=0.01
Accept-Encoding: gzip, deflate, br
Accept-Language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
Cache-Control: no-cache
Connection: keep-alive
Content-Type: application/json; charset=utf-8
Cookie: JSESSIONID=E48CEDD1055018AB7699F8535262534A; ROUTEID=.node2; _gcl_aw=GCL.1586846558.Cj0KCQjwm9D0BRCMARIsAIfvfIZNAOEwSTB07xpMOGovBgjbl78DcVBNsq9yICTMfCYiS3HxJvboiTcaAsuGEALw_wcB; _gcl_au=1.1.1943606019.1586846558; _ga=GA1.2.1209607200.1586846558; _gid=GA1.2.1715717523.1586846558; _gac_UA-132699638-1=1.1586846558.Cj0KCQjwm9D0BRCMARIsAIfvfIZNAOEwSTB07xpMOGovBgjbl78DcVBNsq9yICTMfCYiS3HxJvboiTcaAsuGEALw_wcB; _gat_UA-132699638-1=1; _uetsid=_uet00a459f7-345a-7720-7ff8-6b65c1d225c4
Host: www.nicolas.com
Pragma: no-cache
Referer: https://www.nicolas.com/fr/Vins/c/01/
Sec-Fetch-Dest: empty
Sec-Fetch-Mode: cors
Sec-Fetch-Site: same-origin
User-Agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36
X-Requested-With: XMLHttpRequest"""
    headers=dict([i.strip().split(': ') for i in headers.split('\n')])
    result=r.get(url, headers=headers).json()
    df=pd.json_normalize(result['results'])
    df_final=df_final.append(df)
    time.sleep(2)
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
df_final
# Out:
#    seoMetaData    code                                     name  \
# 0         None  483557                Reuilly Les Landries 2018
# 1         None  485707                      Larroque Rouge 2019
# 2         None  480272                      Larroque Blanc 2017
# 3         None  483124                      Larroque Blanc 2018
# 4         None  482522  Berticot Cuvée Première, Sauvignon 2018
# ..         ...     ...                                      ...
# 14        None  485445                 Beauvignac Viognier 2019
# 15        None  482799                 Plume 9° Chardonnay 2018
# 16        None  484692          St Flo Île de Beauté Rouge 2017
# 17        None  482721              Plume 9° Grenache Rose 2018
# 18        None  479417        Buzet Rouge Costes De Beyrac 2016
#
#                                                   url  \
# 0       /Vins/Reuilly-Les-Landries-2018/p/483557.html
# 1             /Vins/Larroque-Rouge-2019/p/485707.html
# ...

# %%
df_final.columns
# Out:
# Index(['seoMetaData', 'code', 'name', 'url', 'description', 'purchasable',
#        'stock', 'futureStocks', 'availableForPickup', 'averageRating',
#        'numberOfReviews', 'summary', 'manufacturer', 'variantType',
#        'baseProduct', 'images', 'categories', 'reviews', 'classifications',
#        'potentialPromotions', 'variantOptions', 'baseOptions',
#        'volumePricesFlag', 'volumePrices', 'productReferences',
#        'variantMatrix', 'priceRange', 'firstCategoryNameList',
#        'multidimensional', 'configurable', 'addToCartDisabled',
#        'addToCartDisabledMessage', 'keywords', 'libelleBrut', 'excluNicolas',
#        'pcb', 'weight', 'cl', 'doyouknow', 'brand', 'video', 'picto',
#        'picture', 'sticker', 'sustainableDevelopment', 'ean', 'strikePrice',
#        'loyaltyPrice', 'solrDesignation', 'solrRegion', 'solrCountry',
#        'solrContainer', 'cara', 'favStoreStockLevel',
#        'quantityBoughtYersterday', 'typeOfProduct', 'isResupplingProcess',
# ...
